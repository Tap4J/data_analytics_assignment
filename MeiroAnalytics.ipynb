# %% [markdown]
# # Data analysis via pandas

# %% [markdown]
# ## Loading data in jupyter notebook

# %%
# First I'll import libraries I'm going to use
import pandas as pd
import json

# %%
data = []
with open ('dataset/data.ndjson', "r") as file:
    for line in file:
        json_data = json.loads(line)
        data.append(json_data)

# %%
df=pd.DataFrame(data)

# %%
# Control data
df.head()
# Out:
#    id     created                                           products  \
# 0   0  1542328144  [{'id': 0, 'name': 'Product A', 'price': 160},...
# 1   1  1544115833  [{'id': 3, 'name': 'Product D', 'price': 130},...
# 2   2  1540143218  [{'id': 6, 'name': 'Product G', 'price': 100},...
# 3   3  1542051492  [{'id': 6, 'name': 'Product G', 'price': 100},...
# 4   4  1543571130  [{'id': 10, 'name': 'Product K', 'price': 60},...
#
#                                                user
# 0     {'id': 3, 'name': 'User D', 'city': 'Sydney'}
# 1     {'id': 0, 'name': 'User A', 'city': 'Prague'}
# 2     {'id': 0, 'name': 'User A', 'city': 'Prague'}
# 3  {'id': 2, 'name': 'User C', 'city': 'Singapore'}
# 4    {'id': 5, 'name': 'User F', 'city': 'Jakarta'}

# %%
pd.set_option('display.max_colwidth', 1)

# %%
# In the data I can see I have a nested structure inside. Also, column created needs to be converted and adjusted. I continue with simple exploratory analysis
df
# Out:
#           id     created  \
# 0      0      1542328144
# 1      1      1544115833
# 2      2      1540143218
# 3      3      1542051492
# 4      4      1543571130
# ...   ..             ...
# 99995  99995  1537263824
# 99996  99996  1539411617
# 99997  99997  1539889882
# 99998  99998  1539265746
# 99999  99999  1539896610
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            products  \
# 0      [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 8, 'name': 'Product I', 'price': 80}]
# 1      [{'id': 3, 'name': 'Product D', 'price': 130}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 13, 'name': 'Product N', 'price': 30}]
# 2      [{'id': 6, 'name': 'Product G', 'price': 100}, {'id': 7, 'name': 'Product H', 'price': 90}]
# 3      [{'id': 6, 'name': 'Product G', 'price': 100}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 7, 'name': 'Product H', 'price': 90}, {'id': 14, 'name': 'Product O', 'price': 20}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 0, 'name': 'Product A', 'price': 160}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 10, 'name': 'Product K', 'price': 60}]
# 4      [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 12, 'name': 'Product M', 'price': 40}]
# ...                                                                                                                                                                                         ...
# 99995  [{'id': 2, 'name': 'Product C', 'price': 140}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 8, 'name': 'Product I', 'price': 80}]
# 99996  [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 6, 'name': 'Product G', 'price': 100}]
# 99997  [{'id': 15, 'name': 'Product P', 'price': 10}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 1, 'name': 'Product B', 'price': 150}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 4, 'name': 'Product E', 'price': 120}]
# 99998  [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 12, 'name': 'Product M', 'price': 40}]
# 99999  [{'id': 7, 'name': 'Product H', 'price': 90}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 12, 'name': 'Product M', 'price': 40}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 0, 'name': 'Product A', 'price': 160}, {'id': 2, 'name': 'Product C', 'price': 140}]
#
#                                                       user
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}
# 2      {'id': 0, 'name': 'User A', 'city': 'Prague'}
# 3      {'id': 2, 'name': 'User C', 'city': 'Singapore'}
# 4      {'id': 5, 'name': 'User F', 'city': 'Jakarta'}
# ...                                               ...
# 99995  {'id': 0, 'name': 'User A', 'city': 'Prague'}
# 99996  {'id': 4, 'name': 'User E', 'city': 'Melbourne'}
# 99997  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}
# 99998  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}
#
# [100000 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['id', 'created', 'products', 'user'], dtype='object')

# %%
df.dtypes
# Out:
# id          int64
# created     int64
# products    object
# user        object
# dtype: object

# %%
# Check for missing data
print(df.isnull().sum())
# Out:
# id          0
# created     0
# products    0
# user        0
# dtype: int64

# %% [markdown]
# <p> Right now, this is enough. I'll execute preprocesseing and then I continue exploring the data.</p>

# %% [markdown]
# ## Convert column "created" to daytime and determine if day is friday
# <b> In this case, I decided to convert column created into datetime format.

# %%
df['created'] = pd.to_datetime(df['created'], unit='s', utc=True)
df['created'] = df['created'].dt.tz_convert('Europe/Prague')

# %% [markdown]
# <b>Add column for friday

# %%
df['is_friday'] = df['created'].dt.dayofweek == 4
friday_purchase = df[df['is_friday']]
print(friday_purchase)
# Out:
#           id                   created  \
# 0      0     2018-11-16 01:29:04+01:00
# 4      4     2018-11-30 10:45:30+01:00
# 8      8     2018-09-21 02:11:06+02:00
# 15     15    2018-11-16 14:09:34+01:00
# 17     17    2018-10-19 15:33:17+02:00
# ...    ..                          ...
# 99959  99959 2018-11-09 21:10:09+01:00
# 99961  99961 2018-12-07 22:35:11+01:00
# 99970  99970 2018-11-23 14:03:01+01:00
# 99979  99979 2018-11-16 08:34:59+01:00
# 99986  99986 2018-11-09 14:00:16+01:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                           products  \
# 0      [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 8, 'name': 'Product I', 'price': 80}]
# 4      [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 12, 'name': 'Product M', 'price': 40}]
# 8      [{'id': 7, 'name': 'Product H', 'price': 90}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 14, 'name': 'Product O', 'price': 20}, {'id': 12, 'name': 'Product M', 'price': 40}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 7, 'name': 'Product H', 'price': 90}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 1, 'name': 'Product B', 'price': 150}, {'id': 7, 'name': 'Product H', 'price': 90}]
# 15     [{'id': 11, 'name': 'Product L', 'price': 50}, {'id': 9, 'name': 'Product J', 'price': 70}]
# 17     [{'id': 15, 'name': 'Product P', 'price': 10}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 8, 'name': 'Product I', 'price': 80}]
# ...                                                                                                                                          ...
# 99959  [{'id': 2, 'name': 'Product C', 'price': 140}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 1, 'name': 'Product B', 'price': 150}, {'id': 9, 'name': 'Product J', 'price': 70}, {'id': 14, 'name': 'Product O', 'price': 20}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 11, 'name': 'Product L', 'price': 50}]
# 99961  [{'id': 2, 'name': 'Product C', 'price': 140}, {'id': 6, 'name': 'Product G', 'price': 100}, {'id': 7, 'name': 'Product H', 'price': 90}, {'id': 6, 'name': 'Product G', 'price': 100}, {'id': 0, 'name': 'Product A', 'price': 160}, {'id': 9, 'name': 'Product J', 'price': 70}, {'id': 15, 'name': 'Product P', 'price': 10}, {'id': 1, 'name': 'Product B', 'price': 150}, {'id': 9, 'name': 'Product J', 'price': 70}, {'id': 5, 'name': 'Product F', 'price': 110}]
# 99970  [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 7, 'name': 'Product H', 'price': 90}, {'id': 9, 'name': 'Product J', 'price': 70}, {'id': 7, 'name': 'Product H', 'price': 90}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 10, 'name': 'Product K', 'price': 60}]
# 99979  [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 6, 'name': 'Product G', 'price': 100}, {'id': 6, 'name': 'Product G', 'price': 100}, {'id': 12, 'name': 'Product M', 'price': 40}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 14, 'name': 'Product O', 'price': 20}]
# 99986  [{'id': 15, 'name': 'Product P', 'price': 10}, {'id': 14, 'name': 'Product O', 'price': 20}, {'id': 1, 'name': 'Product B', 'price': 150}, {'id': 13, 'name': 'Product N', 'price': 30}]
#
#                                                    user  is_friday
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}     True
# 4      {'id': 5, 'name': 'User F', 'city': 'Jakarta'}    True
# 8      {'id': 0, 'name': 'User A', 'city': 'Prague'}     True
# 15     {'id': 0, 'name': 'User A', 'city': 'Prague'}     True
# 17     {'id': 6, 'name': 'User G', 'city': 'Hong Kong'}  True
# ...                                                 ...   ...
# 99959  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}    True
# 99961  {'id': 3, 'name': 'User D', 'city': 'Sydney'}     True
# 99970  {'id': 3, 'name': 'User D', 'city': 'Sydney'}     True
# 99979  {'id': 2, 'name': 'User C', 'city': 'Singapore'}  True
# 99986  {'id': 1, 'name': 'User B', 'city': 'Brno'}       True
#
# [14391 rows x 5 columns]

# %%
# Control if original df is updated
df
# Out:
#           id                   created  \
# 0      0     2018-11-16 01:29:04+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 2      2     2018-10-21 19:33:38+02:00
# 3      3     2018-11-12 20:38:12+01:00
# 4      4     2018-11-30 10:45:30+01:00
# ...   ..                           ...
# 99995  99995 2018-09-18 11:43:44+02:00
# 99996  99996 2018-10-13 08:20:17+02:00
# 99997  99997 2018-10-18 21:11:22+02:00
# 99998  99998 2018-10-11 15:49:06+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            products  \
# 0      [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 8, 'name': 'Product I', 'price': 80}]
# 1      [{'id': 3, 'name': 'Product D', 'price': 130}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 13, 'name': 'Product N', 'price': 30}]
# 2      [{'id': 6, 'name': 'Product G', 'price': 100}, {'id': 7, 'name': 'Product H', 'price': 90}]
# 3      [{'id': 6, 'name': 'Product G', 'price': 100}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 7, 'name': 'Product H', 'price': 90}, {'id': 14, 'name': 'Product O', 'price': 20}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 0, 'name': 'Product A', 'price': 160}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 10, 'name': 'Product K', 'price': 60}]
# 4      [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 12, 'name': 'Product M', 'price': 40}]
# ...                                                                                                                                                                                         ...
# 99995  [{'id': 2, 'name': 'Product C', 'price': 140}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 8, 'name': 'Product I', 'price': 80}]
# 99996  [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 6, 'name': 'Product G', 'price': 100}]
# 99997  [{'id': 15, 'name': 'Product P', 'price': 10}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 1, 'name': 'Product B', 'price': 150}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 4, 'name': 'Product E', 'price': 120}]
# 99998  [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 12, 'name': 'Product M', 'price': 40}]
# 99999  [{'id': 7, 'name': 'Product H', 'price': 90}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 12, 'name': 'Product M', 'price': 40}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 0, 'name': 'Product A', 'price': 160}, {'id': 2, 'name': 'Product C', 'price': 140}]
#
#                                                       user  is_friday
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 2      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 3      {'id': 2, 'name': 'User C', 'city': 'Singapore'}     False
# 4      {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       True
# ...                                               ...        ...
# 99995  {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 99996  {'id': 4, 'name': 'User E', 'city': 'Melbourne'}     False
# 99997  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       False
# 99998  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
#
# [100000 rows x 5 columns]

# %% [markdown]
# ## Extract data from nested structure into separate columns

# %% [markdown]
# Nested structure of columns products and user will be extracted into separated columns in order to easily access the information and continue the analysis

# %%
# Mapping the products
df['product_id'] = df['products'].apply(lambda x: [product['id'] for product in x])
df['product_name'] = df['products'].apply(lambda x: [product['name'] for product in x])
df['product_price'] = df['products'].apply(lambda x: [product['price'] for product in x])

# %%
df
# Out:
#           id                   created  \
# 0      0     2018-11-16 01:29:04+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 2      2     2018-10-21 19:33:38+02:00
# 3      3     2018-11-12 20:38:12+01:00
# 4      4     2018-11-30 10:45:30+01:00
# ...   ..                           ...
# 99995  99995 2018-09-18 11:43:44+02:00
# 99996  99996 2018-10-13 08:20:17+02:00
# 99997  99997 2018-10-18 21:11:22+02:00
# 99998  99998 2018-10-11 15:49:06+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            products  \
# 0      [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 8, 'name': 'Product I', 'price': 80}]
# 1      [{'id': 3, 'name': 'Product D', 'price': 130}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 13, 'name': 'Product N', 'price': 30}]
# 2      [{'id': 6, 'name': 'Product G', 'price': 100}, {'id': 7, 'name': 'Product H', 'price': 90}]
# 3      [{'id': 6, 'name': 'Product G', 'price': 100}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 7, 'name': 'Product H', 'price': 90}, {'id': 14, 'name': 'Product O', 'price': 20}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 0, 'name': 'Product A', 'price': 160}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 10, 'name': 'Product K', 'price': 60}]
# 4      [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 12, 'name': 'Product M', 'price': 40}]
# ...                                                                                                                                                                                         ...
# 99995  [{'id': 2, 'name': 'Product C', 'price': 140}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 8, 'name': 'Product I', 'price': 80}]
# 99996  [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 6, 'name': 'Product G', 'price': 100}]
# 99997  [{'id': 15, 'name': 'Product P', 'price': 10}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 1, 'name': 'Product B', 'price': 150}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 4, 'name': 'Product E', 'price': 120}]
# 99998  [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 12, 'name': 'Product M', 'price': 40}]
# 99999  [{'id': 7, 'name': 'Product H', 'price': 90}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 12, 'name': 'Product M', 'price': 40}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 0, 'name': 'Product A', 'price': 160}, {'id': 2, 'name': 'Product C', 'price': 140}]
#
#                                                       user  is_friday  \
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 2      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 3      {'id': 2, 'name': 'User C', 'city': 'Singapore'}     False
# 4      {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       True
# ...                                               ...        ...
# 99995  {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 99996  {'id': 4, 'name': 'User E', 'city': 'Melbourne'}     False
# 99997  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       False
# 99998  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
#
#                             product_id  \
# 0      [0, 8]
# 1      [3, 2, 13]
# 2      [6, 7]
# 3      [6, 13, 7, 14, 8, 0, 5, 13, 10]
# 4      [10, 3, 2, 12]
# ...               ...
# 99995  [2, 2, 10, 8]
# 99996  [10, 8, 6]
# 99997  [15, 10, 4, 1, 2, 4, 8, 4]
# 99998  [0, 12]
# 99999  [7, 5, 3, 12, 4, 0, 2]
#
#                                                                                               product_name  \
# 0      [Product A, Product I]
# 1      [Product D, Product C, Product N]
# 2      [Product G, Product H]
# 3      [Product G, Product N, Product H, Product O, Product I, Product A, Product F, Product N, Product K]
# 4      [Product K, Product D, Product C, Product M]
# ...                                             ...
# 99995  [Product C, Product C, Product K, Product I]
# 99996  [Product K, Product I, Product G]
# 99997  [Product P, Product K, Product E, Product B, Product C, Product E, Product I, Product E]
# 99998  [Product A, Product M]
# 99999  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
#
#                                  product_price
# 0      [160, 80]
# 1      [130, 140, 30]
# 2      [100, 90]
# 3      [100, 30, 90, 20, 80, 160, 110, 30, 60]
# 4      [60, 130, 140, 40]
# ...                   ...
# 99995  [140, 140, 60, 80]
# 99996  [60, 80, 100]
# 99997  [10, 60, 120, 150, 140, 120, 80, 120]
# 99998  [160, 40]
# 99999  [90, 110, 130, 40, 120, 160, 140]
#
# [100000 rows x 8 columns]

# %%
# Repeat same for user
df['user_id'] = df['user'].apply(lambda x: x['id'])
df['user_name'] = df['user'].apply(lambda x: x['name'])
df['user_city'] = df['user'].apply(lambda x: x['city'])

# %%
df
# Out:
#           id                   created  \
# 0      0     2018-11-16 01:29:04+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 2      2     2018-10-21 19:33:38+02:00
# 3      3     2018-11-12 20:38:12+01:00
# 4      4     2018-11-30 10:45:30+01:00
# ...   ..                           ...
# 99995  99995 2018-09-18 11:43:44+02:00
# 99996  99996 2018-10-13 08:20:17+02:00
# 99997  99997 2018-10-18 21:11:22+02:00
# 99998  99998 2018-10-11 15:49:06+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            products  \
# 0      [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 8, 'name': 'Product I', 'price': 80}]
# 1      [{'id': 3, 'name': 'Product D', 'price': 130}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 13, 'name': 'Product N', 'price': 30}]
# 2      [{'id': 6, 'name': 'Product G', 'price': 100}, {'id': 7, 'name': 'Product H', 'price': 90}]
# 3      [{'id': 6, 'name': 'Product G', 'price': 100}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 7, 'name': 'Product H', 'price': 90}, {'id': 14, 'name': 'Product O', 'price': 20}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 0, 'name': 'Product A', 'price': 160}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 10, 'name': 'Product K', 'price': 60}]
# 4      [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 12, 'name': 'Product M', 'price': 40}]
# ...                                                                                                                                                                                         ...
# 99995  [{'id': 2, 'name': 'Product C', 'price': 140}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 8, 'name': 'Product I', 'price': 80}]
# 99996  [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 6, 'name': 'Product G', 'price': 100}]
# 99997  [{'id': 15, 'name': 'Product P', 'price': 10}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 1, 'name': 'Product B', 'price': 150}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 4, 'name': 'Product E', 'price': 120}]
# 99998  [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 12, 'name': 'Product M', 'price': 40}]
# 99999  [{'id': 7, 'name': 'Product H', 'price': 90}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 12, 'name': 'Product M', 'price': 40}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 0, 'name': 'Product A', 'price': 160}, {'id': 2, 'name': 'Product C', 'price': 140}]
#
#                                                       user  is_friday  \
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 2      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 3      {'id': 2, 'name': 'User C', 'city': 'Singapore'}     False
# 4      {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       True
# ...                                               ...        ...
# 99995  {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 99996  {'id': 4, 'name': 'User E', 'city': 'Melbourne'}     False
# 99997  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       False
# 99998  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
#
#                             product_id  \
# 0      [0, 8]
# 1      [3, 2, 13]
# 2      [6, 7]
# 3      [6, 13, 7, 14, 8, 0, 5, 13, 10]
# 4      [10, 3, 2, 12]
# ...               ...
# 99995  [2, 2, 10, 8]
# 99996  [10, 8, 6]
# 99997  [15, 10, 4, 1, 2, 4, 8, 4]
# 99998  [0, 12]
# 99999  [7, 5, 3, 12, 4, 0, 2]
#
#                                                                                               product_name  \
# 0      [Product A, Product I]
# 1      [Product D, Product C, Product N]
# 2      [Product G, Product H]
# 3      [Product G, Product N, Product H, Product O, Product I, Product A, Product F, Product N, Product K]
# 4      [Product K, Product D, Product C, Product M]
# ...                                             ...
# 99995  [Product C, Product C, Product K, Product I]
# 99996  [Product K, Product I, Product G]
# 99997  [Product P, Product K, Product E, Product B, Product C, Product E, Product I, Product E]
# 99998  [Product A, Product M]
# 99999  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
#
#                                  product_price  user_id user_name  \
# 0      [160, 80]                                3        User D
# 1      [130, 140, 30]                           0        User A
# 2      [100, 90]                                0        User A
# 3      [100, 30, 90, 20, 80, 160, 110, 30, 60]  2        User C
# 4      [60, 130, 140, 40]                       5        User F
# ...                   ...                      ..           ...
# 99995  [140, 140, 60, 80]                       0        User A
# 99996  [60, 80, 100]                            4        User E
# 99997  [10, 60, 120, 150, 140, 120, 80, 120]    5        User F
# 99998  [160, 40]                                5        User F
# 99999  [90, 110, 130, 40, 120, 160, 140]        7        User H
#
#           user_city
# 0      Sydney
# 1      Prague
# 2      Prague
# 3      Singapore
# 4      Jakarta
# ...        ...
# 99995  Prague
# 99996  Melbourne
# 99997  Jakarta
# 99998  Jakarta
# 99999  Kuala Lumpur
#
# [100000 rows x 11 columns]

# %%
# Creating new column and assigning the row_id to handle analysis. Side note: I already have id but I like to create new range to have the original intact data in case there was an issue during loading the data.
df['row_id'] = range(len(df))

# %%
df
# Out:
#           id                   created  \
# 0      0     2018-11-16 01:29:04+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 2      2     2018-10-21 19:33:38+02:00
# 3      3     2018-11-12 20:38:12+01:00
# 4      4     2018-11-30 10:45:30+01:00
# ...   ..                           ...
# 99995  99995 2018-09-18 11:43:44+02:00
# 99996  99996 2018-10-13 08:20:17+02:00
# 99997  99997 2018-10-18 21:11:22+02:00
# 99998  99998 2018-10-11 15:49:06+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            products  \
# 0      [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 8, 'name': 'Product I', 'price': 80}]
# 1      [{'id': 3, 'name': 'Product D', 'price': 130}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 13, 'name': 'Product N', 'price': 30}]
# 2      [{'id': 6, 'name': 'Product G', 'price': 100}, {'id': 7, 'name': 'Product H', 'price': 90}]
# 3      [{'id': 6, 'name': 'Product G', 'price': 100}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 7, 'name': 'Product H', 'price': 90}, {'id': 14, 'name': 'Product O', 'price': 20}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 0, 'name': 'Product A', 'price': 160}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 13, 'name': 'Product N', 'price': 30}, {'id': 10, 'name': 'Product K', 'price': 60}]
# 4      [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 12, 'name': 'Product M', 'price': 40}]
# ...                                                                                                                                                                                         ...
# 99995  [{'id': 2, 'name': 'Product C', 'price': 140}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 8, 'name': 'Product I', 'price': 80}]
# 99996  [{'id': 10, 'name': 'Product K', 'price': 60}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 6, 'name': 'Product G', 'price': 100}]
# 99997  [{'id': 15, 'name': 'Product P', 'price': 10}, {'id': 10, 'name': 'Product K', 'price': 60}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 1, 'name': 'Product B', 'price': 150}, {'id': 2, 'name': 'Product C', 'price': 140}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 8, 'name': 'Product I', 'price': 80}, {'id': 4, 'name': 'Product E', 'price': 120}]
# 99998  [{'id': 0, 'name': 'Product A', 'price': 160}, {'id': 12, 'name': 'Product M', 'price': 40}]
# 99999  [{'id': 7, 'name': 'Product H', 'price': 90}, {'id': 5, 'name': 'Product F', 'price': 110}, {'id': 3, 'name': 'Product D', 'price': 130}, {'id': 12, 'name': 'Product M', 'price': 40}, {'id': 4, 'name': 'Product E', 'price': 120}, {'id': 0, 'name': 'Product A', 'price': 160}, {'id': 2, 'name': 'Product C', 'price': 140}]
#
#                                                       user  is_friday  \
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 2      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 3      {'id': 2, 'name': 'User C', 'city': 'Singapore'}     False
# 4      {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       True
# ...                                               ...        ...
# 99995  {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 99996  {'id': 4, 'name': 'User E', 'city': 'Melbourne'}     False
# 99997  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       False
# 99998  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}       False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
#
#                             product_id  \
# 0      [0, 8]
# 1      [3, 2, 13]
# 2      [6, 7]
# 3      [6, 13, 7, 14, 8, 0, 5, 13, 10]
# 4      [10, 3, 2, 12]
# ...               ...
# 99995  [2, 2, 10, 8]
# 99996  [10, 8, 6]
# 99997  [15, 10, 4, 1, 2, 4, 8, 4]
# 99998  [0, 12]
# 99999  [7, 5, 3, 12, 4, 0, 2]
#
#                                                                                               product_name  \
# 0      [Product A, Product I]
# 1      [Product D, Product C, Product N]
# 2      [Product G, Product H]
# 3      [Product G, Product N, Product H, Product O, Product I, Product A, Product F, Product N, Product K]
# 4      [Product K, Product D, Product C, Product M]
# ...                                             ...
# 99995  [Product C, Product C, Product K, Product I]
# 99996  [Product K, Product I, Product G]
# 99997  [Product P, Product K, Product E, Product B, Product C, Product E, Product I, Product E]
# 99998  [Product A, Product M]
# 99999  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
#
#                                  product_price  user_id user_name  \
# 0      [160, 80]                                3        User D
# 1      [130, 140, 30]                           0        User A
# 2      [100, 90]                                0        User A
# 3      [100, 30, 90, 20, 80, 160, 110, 30, 60]  2        User C
# 4      [60, 130, 140, 40]                       5        User F
# ...                   ...                      ..           ...
# 99995  [140, 140, 60, 80]                       0        User A
# 99996  [60, 80, 100]                            4        User E
# 99997  [10, 60, 120, 150, 140, 120, 80, 120]    5        User F
# 99998  [160, 40]                                5        User F
# 99999  [90, 110, 130, 40, 120, 160, 140]        7        User H
#
#           user_city  row_id
# 0      Sydney        0
# 1      Prague        1
# 2      Prague        2
# 3      Singapore     3
# 4      Jakarta       4
# ...        ...      ..
# 99995  Prague        99995
# 99996  Melbourne     99996
# 99997  Jakarta       99997
# 99998  Jakarta       99998
# 99999  Kuala Lumpur  99999
#
# [100000 rows x 12 columns]

# %% [markdown]
# ## Creating new df_expanded and exploding multiple values into new rows

# %%
df['product_counts'] = df['products'].apply(lambda x: pd.Series([item['id'] for item in x]).value_counts().to_dict())

# Create a list to hold the exploded rows
exploded_rows = []

# Iterate over each row and explode based on product counts
for _, row in df.iterrows():
    order_id = _  # Use the index as order_id
    product_counts = row['product_counts']

    for product_id, quantity in product_counts.items():
        exploded_rows.append({'order_id': order_id, 'product_id': product_id, 'quantity': quantity})

exploded_df = pd.DataFrame(exploded_rows)

# Merge with the original DataFrame
df_expanded = exploded_df.merge(df.explode('products'), left_on='order_id', right_index=True)

# Drop unnecessary columns
df_expanded = df_expanded.drop(columns=['products', 'product_counts'])

# Print the result
print(df_expanded)
# Out:
#         order_id  product_id_x  quantity     id                   created  \
# 0       0         0             1         0     2018-11-16 01:29:04+01:00
# 0       0         0             1         0     2018-11-16 01:29:04+01:00
# 1       0         8             1         0     2018-11-16 01:29:04+01:00
# 1       0         8             1         0     2018-11-16 01:29:04+01:00
# 2       1         3             1         1     2018-12-06 18:03:53+01:00
# ...    ..        ..            ..        ..                           ...
# 458075  99999     2             1         99999 2018-10-18 23:03:30+02:00
# 458075  99999     2             1         99999 2018-10-18 23:03:30+02:00
# 458075  99999     2             1         99999 2018-10-18 23:03:30+02:00
# 458075  99999     2             1         99999 2018-10-18 23:03:30+02:00
# 458075  99999     2             1         99999 2018-10-18 23:03:30+02:00
#
#                                                        user  is_friday  \
# 0       {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 0       {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 1       {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 1       {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 2       {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# ...                                               ...          ...
# 458075  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 458075  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 458075  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 458075  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 458075  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
#
#                   product_id_y  \
# 0       [0, 8]
# 0       [0, 8]
# 1       [0, 8]
# 1       [0, 8]
# 2       [3, 2, 13]
# ...            ...
# 458075  [7, 5, 3, 12, 4, 0, 2]
# 458075  [7, 5, 3, 12, 4, 0, 2]
# 458075  [7, 5, 3, 12, 4, 0, 2]
# 458075  [7, 5, 3, 12, 4, 0, 2]
# 458075  [7, 5, 3, 12, 4, 0, 2]
#
#                                                                          product_name  \
# 0       [Product A, Product I]
# 0       [Product A, Product I]
# 1       [Product A, Product I]
# 1       [Product A, Product I]
# 2       [Product D, Product C, Product N]
# ...                                   ...
# 458075  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
# 458075  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
# 458075  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
# 458075  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
# 458075  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
#
#                             product_price  user_id user_name     user_city  \
# 0       [160, 80]                          3        User D    Sydney
# 0       [160, 80]                          3        User D    Sydney
# 1       [160, 80]                          3        User D    Sydney
# 1       [160, 80]                          3        User D    Sydney
# 2       [130, 140, 30]                     0        User A    Prague
# ...                ...                    ..           ...       ...
# 458075  [90, 110, 130, 40, 120, 160, 140]  7        User H    Kuala Lumpur
# 458075  [90, 110, 130, 40, 120, 160, 140]  7        User H    Kuala Lumpur
# 458075  [90, 110, 130, 40, 120, 160, 140]  7        User H    Kuala Lumpur
# 458075  [90, 110, 130, 40, 120, 160, 140]  7        User H    Kuala Lumpur
# 458075  [90, 110, 130, 40, 120, 160, 140]  7        User H    Kuala Lumpur
#
#         row_id
# 0       0
# 0       0
# 1       0
# 1       0
# 2       1
# ...    ..
# 458075  99999
# 458075  99999
# 458075  99999
# 458075  99999
# 458075  99999
#
# [3122781 rows x 14 columns]

# %%
df_expanded
# Out:
#         order_id  product_id_x  quantity     id                   created  \
# 0       0         0             1         0     2018-11-16 01:29:04+01:00
# 0       0         0             1         0     2018-11-16 01:29:04+01:00
# 1       0         8             1         0     2018-11-16 01:29:04+01:00
# 1       0         8             1         0     2018-11-16 01:29:04+01:00
# 2       1         3             1         1     2018-12-06 18:03:53+01:00
# ...    ..        ..            ..        ..                           ...
# 458075  99999     2             1         99999 2018-10-18 23:03:30+02:00
# 458075  99999     2             1         99999 2018-10-18 23:03:30+02:00
# 458075  99999     2             1         99999 2018-10-18 23:03:30+02:00
# 458075  99999     2             1         99999 2018-10-18 23:03:30+02:00
# 458075  99999     2             1         99999 2018-10-18 23:03:30+02:00
#
#                                                        user  is_friday  \
# 0       {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 0       {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 1       {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 1       {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 2       {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# ...                                               ...          ...
# 458075  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 458075  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 458075  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 458075  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 458075  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
#
#                   product_id_y  \
# 0       [0, 8]
# 0       [0, 8]
# 1       [0, 8]
# 1       [0, 8]
# 2       [3, 2, 13]
# ...            ...
# 458075  [7, 5, 3, 12, 4, 0, 2]
# 458075  [7, 5, 3, 12, 4, 0, 2]
# 458075  [7, 5, 3, 12, 4, 0, 2]
# 458075  [7, 5, 3, 12, 4, 0, 2]
# 458075  [7, 5, 3, 12, 4, 0, 2]
#
#                                                                          product_name  \
# 0       [Product A, Product I]
# 0       [Product A, Product I]
# 1       [Product A, Product I]
# 1       [Product A, Product I]
# 2       [Product D, Product C, Product N]
# ...                                   ...
# 458075  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
# 458075  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
# 458075  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
# 458075  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
# 458075  [Product H, Product F, Product D, Product M, Product E, Product A, Product C]
#
#                             product_price  user_id user_name     user_city  \
# 0       [160, 80]                          3        User D    Sydney
# 0       [160, 80]                          3        User D    Sydney
# 1       [160, 80]                          3        User D    Sydney
# 1       [160, 80]                          3        User D    Sydney
# 2       [130, 140, 30]                     0        User A    Prague
# ...                ...                    ..           ...       ...
# 458075  [90, 110, 130, 40, 120, 160, 140]  7        User H    Kuala Lumpur
# 458075  [90, 110, 130, 40, 120, 160, 140]  7        User H    Kuala Lumpur
# 458075  [90, 110, 130, 40, 120, 160, 140]  7        User H    Kuala Lumpur
# 458075  [90, 110, 130, 40, 120, 160, 140]  7        User H    Kuala Lumpur
# 458075  [90, 110, 130, 40, 120, 160, 140]  7        User H    Kuala Lumpur
#
#         row_id
# 0       0
# 0       0
# 1       0
# 1       0
# 2       1
# ...    ..
# 458075  99999
# 458075  99999
# 458075  99999
# 458075  99999
# 458075  99999
#
# [3122781 rows x 14 columns]

# %%
df_expanded = df.explode('products')

# %%
df_expanded['product_id'] = df_expanded['products'].apply(lambda x: x['id'])
df_expanded['product_name'] = df_expanded['products'].apply(lambda x: x['name'])
df_expanded['product_price'] = df_expanded['products'].apply(lambda x: x['price'])
df_expanded['quantity'] = df_expanded.apply(lambda row: row['product_id'], axis=1).map(df['product_counts'])

# %%
df_expanded
# Out:
#           id                   created  \
# 0      0     2018-11-16 01:29:04+01:00
# 0      0     2018-11-16 01:29:04+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 1      1     2018-12-06 18:03:53+01:00
# ...   ..                           ...
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
#
#                                            products  \
# 0      {'id': 0, 'name': 'Product A', 'price': 160}
# 0      {'id': 8, 'name': 'Product I', 'price': 80}
# 1      {'id': 3, 'name': 'Product D', 'price': 130}
# 1      {'id': 2, 'name': 'Product C', 'price': 140}
# 1      {'id': 13, 'name': 'Product N', 'price': 30}
# ...                                             ...
# 99999  {'id': 3, 'name': 'Product D', 'price': 130}
# 99999  {'id': 12, 'name': 'Product M', 'price': 40}
# 99999  {'id': 4, 'name': 'Product E', 'price': 120}
# 99999  {'id': 0, 'name': 'Product A', 'price': 160}
# 99999  {'id': 2, 'name': 'Product C', 'price': 140}
#
#                                                       user  is_friday  \
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# ...                                              ...          ...
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
#
#        product_id product_name  product_price  user_id user_name  \
# 0      0           Product A    160            3        User D
# 0      8           Product I    80             3        User D
# 1      3           Product D    130            0        User A
# 1      2           Product C    140            0        User A
# 1      13          Product N    30             0        User A
# ...    ..                ...    ..            ..           ...
# 99999  3           Product D    130            7        User H
# 99999  12          Product M    40             7        User H
# 99999  4           Product E    120            7        User H
# 99999  0           Product A    160            7        User H
# 99999  2           Product C    140            7        User H
#
#           user_city  row_id                               product_counts  \
# 0      Sydney        0       {0: 1, 8: 1}
# 0      Sydney        0       {0: 1, 8: 1}
# 1      Prague        1       {3: 1, 2: 1, 13: 1}
# 1      Prague        1       {3: 1, 2: 1, 13: 1}
# 1      Prague        1       {3: 1, 2: 1, 13: 1}
# ...       ...       ..                       ...
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
#
#                                                   quantity
# 0      {0: 1, 8: 1}
# 0      {7: 3, 5: 1, 14: 1, 12: 1, 8: 1, 10: 1, 1: 1}
# 1      {13: 2, 6: 1, 7: 1, 14: 1, 8: 1, 0: 1, 5: 1, 10: 1}
# 1      {6: 1, 7: 1}
# 1      {3: 1, 9: 1, 13: 1, 5: 1, 14: 1, 0: 1}
# ...                                       ...
# 99999  {13: 2, 6: 1, 7: 1, 14: 1, 8: 1, 0: 1, 5: 1, 10: 1}
# 99999  {12: 2, 2: 1, 14: 1, 8: 1, 0: 1, 3: 1}
# 99999  {10: 1, 3: 1, 2: 1, 12: 1}
# 99999  {0: 1, 8: 1}
# 99999  {6: 1, 7: 1}
#
# [549145 rows x 14 columns]

# %%
df_expanded['quantity'] = df_expanded.groupby('id')['id'].transform('count')

# %%
df_expanded.head(20)
# Out:
#    id                   created                                      products  \
# 0  0  2018-11-16 01:29:04+01:00  {'id': 0, 'name': 'Product A', 'price': 160}
# 0  0  2018-11-16 01:29:04+01:00  {'id': 8, 'name': 'Product I', 'price': 80}
# 1  1  2018-12-06 18:03:53+01:00  {'id': 3, 'name': 'Product D', 'price': 130}
# 1  1  2018-12-06 18:03:53+01:00  {'id': 2, 'name': 'Product C', 'price': 140}
# 1  1  2018-12-06 18:03:53+01:00  {'id': 13, 'name': 'Product N', 'price': 30}
# 2  2  2018-10-21 19:33:38+02:00  {'id': 6, 'name': 'Product G', 'price': 100}
# 2  2  2018-10-21 19:33:38+02:00  {'id': 7, 'name': 'Product H', 'price': 90}
# 3  3  2018-11-12 20:38:12+01:00  {'id': 6, 'name': 'Product G', 'price': 100}
# 3  3  2018-11-12 20:38:12+01:00  {'id': 13, 'name': 'Product N', 'price': 30}
# 3  3  2018-11-12 20:38:12+01:00  {'id': 7, 'name': 'Product H', 'price': 90}
# 3  3  2018-11-12 20:38:12+01:00  {'id': 14, 'name': 'Product O', 'price': 20}
# 3  3  2018-11-12 20:38:12+01:00  {'id': 8, 'name': 'Product I', 'price': 80}
# 3  3  2018-11-12 20:38:12+01:00  {'id': 0, 'name': 'Product A', 'price': 160}
# 3  3  2018-11-12 20:38:12+01:00  {'id': 5, 'name': 'Product F', 'price': 110}
# 3  3  2018-11-12 20:38:12+01:00  {'id': 13, 'name': 'Product N', 'price': 30}
# 3  3  2018-11-12 20:38:12+01:00  {'id': 10, 'name': 'Product K', 'price': 60}
# 4  4  2018-11-30 10:45:30+01:00  {'id': 10, 'name': 'Product K', 'price': 60}
# 4  4  2018-11-30 10:45:30+01:00  {'id': 3, 'name': 'Product D', 'price': 130}
# 4  4  2018-11-30 10:45:30+01:00  {'id': 2, 'name': 'Product C', 'price': 140}
# 4  4  2018-11-30 10:45:30+01:00  {'id': 12, 'name': 'Product M', 'price': 40}
#
#                                                user  is_friday  product_id  \
# 0  {'id': 3, 'name': 'User D', 'city': 'Sydney'}     True       0
# 0  {'id': 3, 'name': 'User D', 'city': 'Sydney'}     True       8
# 1  {'id': 0, 'name': 'User A', 'city': 'Prague'}     False      3
# 1  {'id': 0, 'name': 'User A', 'city': 'Prague'}     False      2
# 1  {'id': 0, 'name': 'User A', 'city': 'Prague'}     False      13
# 2  {'id': 0, 'name': 'User A', 'city': 'Prague'}     False      6
# 2  {'id': 0, 'name': 'User A', 'city': 'Prague'}     False      7
# 3  {'id': 2, 'name': 'User C', 'city': 'Singapore'}  False      6
# 3  {'id': 2, 'name': 'User C', 'city': 'Singapore'}  False      13
# 3  {'id': 2, 'name': 'User C', 'city': 'Singapore'}  False      7
# 3  {'id': 2, 'name': 'User C', 'city': 'Singapore'}  False      14
# 3  {'id': 2, 'name': 'User C', 'city': 'Singapore'}  False      8
# 3  {'id': 2, 'name': 'User C', 'city': 'Singapore'}  False      0
# 3  {'id': 2, 'name': 'User C', 'city': 'Singapore'}  False      5
# 3  {'id': 2, 'name': 'User C', 'city': 'Singapore'}  False      13
# 3  {'id': 2, 'name': 'User C', 'city': 'Singapore'}  False      10
# 4  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}    True       10
# 4  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}    True       3
# 4  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}    True       2
# 4  {'id': 5, 'name': 'User F', 'city': 'Jakarta'}    True       12
#
#   product_name  product_price  user_id user_name  user_city  row_id  \
# 0  Product A    160            3        User D    Sydney     0
# 0  Product I    80             3        User D    Sydney     0
# 1  Product D    130            0        User A    Prague     1
# 1  Product C    140            0        User A    Prague     1
# 1  Product N    30             0        User A    Prague     1
# 2  Product G    100            0        User A    Prague     2
# 2  Product H    90             0        User A    Prague     2
# 3  Product G    100            2        User C    Singapore  3
# 3  Product N    30             2        User C    Singapore  3
# 3  Product H    90             2        User C    Singapore  3
# 3  Product O    20             2        User C    Singapore  3
# 3  Product I    80             2        User C    Singapore  3
# 3  Product A    160            2        User C    Singapore  3
# 3  Product F    110            2        User C    Singapore  3
# 3  Product N    30             2        User C    Singapore  3
# 3  Product K    60             2        User C    Singapore  3
# 4  Product K    60             5        User F    Jakarta    4
# 4  Product D    130            5        User F    Jakarta    4
# 4  Product C    140            5        User F    Jakarta    4
# 4  Product M    40             5        User F    Jakarta    4
#
#                                         product_counts  quantity
# 0  {0: 1, 8: 1}                                         2
# 0  {0: 1, 8: 1}                                         2
# 1  {3: 1, 2: 1, 13: 1}                                  3
# 1  {3: 1, 2: 1, 13: 1}                                  3
# 1  {3: 1, 2: 1, 13: 1}                                  3
# 2  {6: 1, 7: 1}                                         2
# 2  {6: 1, 7: 1}                                         2
# 3  {13: 2, 6: 1, 7: 1, 14: 1, 8: 1, 0: 1, 5: 1, 10: 1}  9
# 3  {13: 2, 6: 1, 7: 1, 14: 1, 8: 1, 0: 1, 5: 1, 10: 1}  9
# 3  {13: 2, 6: 1, 7: 1, 14: 1, 8: 1, 0: 1, 5: 1, 10: 1}  9
# 3  {13: 2, 6: 1, 7: 1, 14: 1, 8: 1, 0: 1, 5: 1, 10: 1}  9
# 3  {13: 2, 6: 1, 7: 1, 14: 1, 8: 1, 0: 1, 5: 1, 10: 1}  9
# 3  {13: 2, 6: 1, 7: 1, 14: 1, 8: 1, 0: 1, 5: 1, 10: 1}  9
# 3  {13: 2, 6: 1, 7: 1, 14: 1, 8: 1, 0: 1, 5: 1, 10: 1}  9
# 3  {13: 2, 6: 1, 7: 1, 14: 1, 8: 1, 0: 1, 5: 1, 10: 1}  9
# 3  {13: 2, 6: 1, 7: 1, 14: 1, 8: 1, 0: 1, 5: 1, 10: 1}  9
# 4  {10: 1, 3: 1, 2: 1, 12: 1}                           4
# 4  {10: 1, 3: 1, 2: 1, 12: 1}                           4
# 4  {10: 1, 3: 1, 2: 1, 12: 1}                           4
# 4  {10: 1, 3: 1, 2: 1, 12: 1}                           4

# %% [markdown]
# ## Check exploded data

# %%
# Check missing data
(df_expanded.isnull().sum())
# Out:
# id                0
# created           0
# products          0
# user              0
# is_friday         0
# product_id        0
# product_name      0
# product_price     0
# user_id           0
# user_name         0
# user_city         0
# row_id            0
# product_counts    0
# quantity          0
# dtype: int64

# %%
# Unique values in a column product_name
print(df_expanded['product_name'].unique())

# Value counts product_name
print(df_expanded['product_name'].value_counts())
# Out:
# ['Product A' 'Product I' 'Product D' 'Product C' 'Product N' 'Product G'
#  'Product H' 'Product O' 'Product F' 'Product K' 'Product M' 'Product B'
#  'Product L' 'Product J' 'Product E' 'Product P']
# product_name
# Product J    34576
# Product L    34567
# Product I    34455
# Product M    34402
# Product B    34392
# Product C    34372
# Product D    34366
# Product O    34346
# Product K    34345
# Product E    34316
# Product P    34288
# Product A    34265
# Product N    34222
# Product G    34152
# Product F    34054
# Product H    34027
# Name: count, dtype: int64

# %%
total_rows = df_expanded.shape[0]
print("Total Rows:", total_rows)
# Out:
# Total Rows: 549145

# %%
# Unique values in a column product_name
print(df_expanded['user_city'].unique())
print(df_expanded['user_name'].unique())
# Out:
# ['Sydney' 'Prague' 'Singapore' 'Jakarta' 'Melbourne' 'Kuala Lumpur'
#  'Hong Kong' 'Brno']
# ['User D' 'User A' 'User C' 'User F' 'User E' 'User H' 'User G' 'User B']

# %% [markdown]
# ## Question 1: Spending users on all fridays

# %% [markdown]
# Answering the question "Which user spent the most money on products on all Fridays?"

# %%
# Selecting only fridays from adjusted df
only_friday = df_expanded[df_expanded['is_friday']]

# %%
only_friday.head(20)
# Out:
#     id                   created  \
# 0   0  2018-11-16 01:29:04+01:00
# 0   0  2018-11-16 01:29:04+01:00
# 4   4  2018-11-30 10:45:30+01:00
# 4   4  2018-11-30 10:45:30+01:00
# 4   4  2018-11-30 10:45:30+01:00
# 4   4  2018-11-30 10:45:30+01:00
# 8   8  2018-09-21 02:11:06+02:00
# 8   8  2018-09-21 02:11:06+02:00
# 8   8  2018-09-21 02:11:06+02:00
# 8   8  2018-09-21 02:11:06+02:00
# 8   8  2018-09-21 02:11:06+02:00
# 8   8  2018-09-21 02:11:06+02:00
# 8   8  2018-09-21 02:11:06+02:00
# 8   8  2018-09-21 02:11:06+02:00
# 8   8  2018-09-21 02:11:06+02:00
# 15  15 2018-11-16 14:09:34+01:00
# 15  15 2018-11-16 14:09:34+01:00
# 17  17 2018-10-19 15:33:17+02:00
# 17  17 2018-10-19 15:33:17+02:00
# 17  17 2018-10-19 15:33:17+02:00
#
#                                         products  \
# 0   {'id': 0, 'name': 'Product A', 'price': 160}
# 0   {'id': 8, 'name': 'Product I', 'price': 80}
# 4   {'id': 10, 'name': 'Product K', 'price': 60}
# 4   {'id': 3, 'name': 'Product D', 'price': 130}
# 4   {'id': 2, 'name': 'Product C', 'price': 140}
# 4   {'id': 12, 'name': 'Product M', 'price': 40}
# 8   {'id': 7, 'name': 'Product H', 'price': 90}
# 8   {'id': 5, 'name': 'Product F', 'price': 110}
# 8   {'id': 14, 'name': 'Product O', 'price': 20}
# 8   {'id': 12, 'name': 'Product M', 'price': 40}
# 8   {'id': 8, 'name': 'Product I', 'price': 80}
# 8   {'id': 7, 'name': 'Product H', 'price': 90}
# 8   {'id': 10, 'name': 'Product K', 'price': 60}
# 8   {'id': 1, 'name': 'Product B', 'price': 150}
# 8   {'id': 7, 'name': 'Product H', 'price': 90}
# 15  {'id': 11, 'name': 'Product L', 'price': 50}
# 15  {'id': 9, 'name': 'Product J', 'price': 70}
# 17  {'id': 15, 'name': 'Product P', 'price': 10}
# 17  {'id': 5, 'name': 'Product F', 'price': 110}
# 17  {'id': 8, 'name': 'Product I', 'price': 80}
#
#                                                 user  is_friday  product_id  \
# 0   {'id': 3, 'name': 'User D', 'city': 'Sydney'}     True       0
# 0   {'id': 3, 'name': 'User D', 'city': 'Sydney'}     True       8
# 4   {'id': 5, 'name': 'User F', 'city': 'Jakarta'}    True       10
# 4   {'id': 5, 'name': 'User F', 'city': 'Jakarta'}    True       3
# 4   {'id': 5, 'name': 'User F', 'city': 'Jakarta'}    True       2
# 4   {'id': 5, 'name': 'User F', 'city': 'Jakarta'}    True       12
# 8   {'id': 0, 'name': 'User A', 'city': 'Prague'}     True       7
# 8   {'id': 0, 'name': 'User A', 'city': 'Prague'}     True       5
# 8   {'id': 0, 'name': 'User A', 'city': 'Prague'}     True       14
# 8   {'id': 0, 'name': 'User A', 'city': 'Prague'}     True       12
# 8   {'id': 0, 'name': 'User A', 'city': 'Prague'}     True       8
# 8   {'id': 0, 'name': 'User A', 'city': 'Prague'}     True       7
# 8   {'id': 0, 'name': 'User A', 'city': 'Prague'}     True       10
# 8   {'id': 0, 'name': 'User A', 'city': 'Prague'}     True       1
# 8   {'id': 0, 'name': 'User A', 'city': 'Prague'}     True       7
# 15  {'id': 0, 'name': 'User A', 'city': 'Prague'}     True       11
# 15  {'id': 0, 'name': 'User A', 'city': 'Prague'}     True       9
# 17  {'id': 6, 'name': 'User G', 'city': 'Hong Kong'}  True       15
# 17  {'id': 6, 'name': 'User G', 'city': 'Hong Kong'}  True       5
# 17  {'id': 6, 'name': 'User G', 'city': 'Hong Kong'}  True       8
#
#    product_name  product_price  user_id user_name  user_city  row_id  \
# 0   Product A    160            3        User D    Sydney     0
# 0   Product I    80             3        User D    Sydney     0
# 4   Product K    60             5        User F    Jakarta    4
# 4   Product D    130            5        User F    Jakarta    4
# 4   Product C    140            5        User F    Jakarta    4
# 4   Product M    40             5        User F    Jakarta    4
# 8   Product H    90             0        User A    Prague     8
# 8   Product F    110            0        User A    Prague     8
# 8   Product O    20             0        User A    Prague     8
# 8   Product M    40             0        User A    Prague     8
# 8   Product I    80             0        User A    Prague     8
# 8   Product H    90             0        User A    Prague     8
# 8   Product K    60             0        User A    Prague     8
# 8   Product B    150            0        User A    Prague     8
# 8   Product H    90             0        User A    Prague     8
# 15  Product L    50             0        User A    Prague     15
# 15  Product J    70             0        User A    Prague     15
# 17  Product P    10             6        User G    Hong Kong  17
# 17  Product F    110            6        User G    Hong Kong  17
# 17  Product I    80             6        User G    Hong Kong  17
#
#                                    product_counts  quantity
# 0   {0: 1, 8: 1}                                   2
# 0   {0: 1, 8: 1}                                   2
# 4   {10: 1, 3: 1, 2: 1, 12: 1}                     4
# 4   {10: 1, 3: 1, 2: 1, 12: 1}                     4
# 4   {10: 1, 3: 1, 2: 1, 12: 1}                     4
# 4   {10: 1, 3: 1, 2: 1, 12: 1}                     4
# 8   {7: 3, 5: 1, 14: 1, 12: 1, 8: 1, 10: 1, 1: 1}  9
# 8   {7: 3, 5: 1, 14: 1, 12: 1, 8: 1, 10: 1, 1: 1}  9
# 8   {7: 3, 5: 1, 14: 1, 12: 1, 8: 1, 10: 1, 1: 1}  9
# 8   {7: 3, 5: 1, 14: 1, 12: 1, 8: 1, 10: 1, 1: 1}  9
# 8   {7: 3, 5: 1, 14: 1, 12: 1, 8: 1, 10: 1, 1: 1}  9
# 8   {7: 3, 5: 1, 14: 1, 12: 1, 8: 1, 10: 1, 1: 1}  9
# 8   {7: 3, 5: 1, 14: 1, 12: 1, 8: 1, 10: 1, 1: 1}  9
# 8   {7: 3, 5: 1, 14: 1, 12: 1, 8: 1, 10: 1, 1: 1}  9
# 8   {7: 3, 5: 1, 14: 1, 12: 1, 8: 1, 10: 1, 1: 1}  9
# 15  {11: 1, 9: 1}                                  2
# 15  {11: 1, 9: 1}                                  2
# 17  {15: 1, 5: 1, 8: 1}                            3
# 17  {15: 1, 5: 1, 8: 1}                            3
# 17  {15: 1, 5: 1, 8: 1}                            3

# %%
spending_row_id = df_expanded[df_expanded['is_friday'] & (df_expanded['row_id'] == 15 )]
row_id = spending_row_id.groupby('user_id')['product_price'].sum()
row_id
# Out:
# user_id
# 0    120
# Name: product_price, dtype: int64

# %%
# Grouping by row_id and summing product_prices
total_spending_row = only_friday.groupby('user_id')['product_price'].sum()

# %%
total_spending_row.sort_values(ascending=False)
# Out:
# user_id
# 4    869810
# 1    862980
# 5    855470
# 2    835880
# 3    831690
# 7    825720
# 6    825350
# 0    814700
# Name: product_price, dtype: int64

# %% [markdown]
# ## Most money spent in all Fridays was by user E with id = 4, out of city Melbourne when purchasing multiple products in total cumulative price of 869810 (in corresponding currency)

# %% [markdown]
# ## Question 2: best 3 products in each location of a user based on quantity

# %%
df_expanded
# Out:
#           id                   created  \
# 0      0     2018-11-16 01:29:04+01:00
# 0      0     2018-11-16 01:29:04+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 1      1     2018-12-06 18:03:53+01:00
# ...   ..                           ...
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
#
#                                            products  \
# 0      {'id': 0, 'name': 'Product A', 'price': 160}
# 0      {'id': 8, 'name': 'Product I', 'price': 80}
# 1      {'id': 3, 'name': 'Product D', 'price': 130}
# 1      {'id': 2, 'name': 'Product C', 'price': 140}
# 1      {'id': 13, 'name': 'Product N', 'price': 30}
# ...                                             ...
# 99999  {'id': 3, 'name': 'Product D', 'price': 130}
# 99999  {'id': 12, 'name': 'Product M', 'price': 40}
# 99999  {'id': 4, 'name': 'Product E', 'price': 120}
# 99999  {'id': 0, 'name': 'Product A', 'price': 160}
# 99999  {'id': 2, 'name': 'Product C', 'price': 140}
#
#                                                       user  is_friday  \
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# ...                                              ...          ...
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
#
#        product_id product_name  product_price  user_id user_name  \
# 0      0           Product A    160            3        User D
# 0      8           Product I    80             3        User D
# 1      3           Product D    130            0        User A
# 1      2           Product C    140            0        User A
# 1      13          Product N    30             0        User A
# ...    ..                ...    ..            ..           ...
# 99999  3           Product D    130            7        User H
# 99999  12          Product M    40             7        User H
# 99999  4           Product E    120            7        User H
# 99999  0           Product A    160            7        User H
# 99999  2           Product C    140            7        User H
#
#           user_city  row_id                               product_counts  \
# 0      Sydney        0       {0: 1, 8: 1}
# 0      Sydney        0       {0: 1, 8: 1}
# 1      Prague        1       {3: 1, 2: 1, 13: 1}
# 1      Prague        1       {3: 1, 2: 1, 13: 1}
# 1      Prague        1       {3: 1, 2: 1, 13: 1}
# ...       ...       ..                       ...
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
#
#        quantity
# 0      2
# 0      2
# 1      3
# 1      3
# 1      3
# ...   ..
# 99999  7
# 99999  7
# 99999  7
# 99999  7
# 99999  7
#
# [549145 rows x 14 columns]

# %%
# Expand for user
df_expanded['user_id'] = df_expanded['user'].apply(lambda x: x['id'])
df_expanded['user_name'] = df_expanded['user'].apply(lambda x: x['name'])
df_expanded['user_city'] = df_expanded['user'].apply(lambda x: x['city'])

# %%
df_expanded
# Out:
#           id                   created  \
# 0      0     2018-11-16 01:29:04+01:00
# 0      0     2018-11-16 01:29:04+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 1      1     2018-12-06 18:03:53+01:00
# ...   ..                           ...
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
#
#                                            products  \
# 0      {'id': 0, 'name': 'Product A', 'price': 160}
# 0      {'id': 8, 'name': 'Product I', 'price': 80}
# 1      {'id': 3, 'name': 'Product D', 'price': 130}
# 1      {'id': 2, 'name': 'Product C', 'price': 140}
# 1      {'id': 13, 'name': 'Product N', 'price': 30}
# ...                                             ...
# 99999  {'id': 3, 'name': 'Product D', 'price': 130}
# 99999  {'id': 12, 'name': 'Product M', 'price': 40}
# 99999  {'id': 4, 'name': 'Product E', 'price': 120}
# 99999  {'id': 0, 'name': 'Product A', 'price': 160}
# 99999  {'id': 2, 'name': 'Product C', 'price': 140}
#
#                                                       user  is_friday  \
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        True
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        False
# ...                                              ...          ...
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  False
#
#        product_id product_name  product_price  user_id user_name  \
# 0      0           Product A    160            3        User D
# 0      8           Product I    80             3        User D
# 1      3           Product D    130            0        User A
# 1      2           Product C    140            0        User A
# 1      13          Product N    30             0        User A
# ...    ..                ...    ..            ..           ...
# 99999  3           Product D    130            7        User H
# 99999  12          Product M    40             7        User H
# 99999  4           Product E    120            7        User H
# 99999  0           Product A    160            7        User H
# 99999  2           Product C    140            7        User H
#
#           user_city  row_id                               product_counts  \
# 0      Sydney        0       {0: 1, 8: 1}
# 0      Sydney        0       {0: 1, 8: 1}
# 1      Prague        1       {3: 1, 2: 1, 13: 1}
# 1      Prague        1       {3: 1, 2: 1, 13: 1}
# 1      Prague        1       {3: 1, 2: 1, 13: 1}
# ...       ...       ..                       ...
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
# 99999  Kuala Lumpur  99999   {7: 1, 5: 1, 3: 1, 12: 1, 4: 1, 0: 1, 2: 1}
#
#        quantity
# 0      2
# 0      2
# 1      3
# 1      3
# 1      3
# ...   ..
# 99999  7
# 99999  7
# 99999  7
# 99999  7
# 99999  7
#
# [549145 rows x 14 columns]

# %%
# Drop not important columns and adjust order if neccessary
columns_to_drop = ['is_friday', 'product_price_total']
df_expanded = df_expanded.drop(columns=columns_to_drop)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[236], line 3
#       1 # Drop not important columns and adjust order
#       2 columns_to_drop = ['is_friday', 'product_price_total']
# ----> 3 df_expanded = df_expanded.drop(columns=columns_to_drop)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['is_friday', 'product_price_total'] not found in axis"

# %%
column_order = ['id', 'created', 'products', 'user', 'product_id', 'product_name', 'product_price', 'user_id', 'user_name', 'user_city', 'row_id' ]
df_expanded = df_expanded[column_order]

# %%
df_expanded
# Out:
#           id                   created  \
# 0      0     2018-11-16 01:29:04+01:00
# 0      0     2018-11-16 01:29:04+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 1      1     2018-12-06 18:03:53+01:00
# 1      1     2018-12-06 18:03:53+01:00
# ...   ..                           ...
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
# 99999  99999 2018-10-18 23:03:30+02:00
#
#                                            products  \
# 0      {'id': 0, 'name': 'Product A', 'price': 160}
# 0      {'id': 8, 'name': 'Product I', 'price': 80}
# 1      {'id': 3, 'name': 'Product D', 'price': 130}
# 1      {'id': 2, 'name': 'Product C', 'price': 140}
# 1      {'id': 13, 'name': 'Product N', 'price': 30}
# ...                                             ...
# 99999  {'id': 3, 'name': 'Product D', 'price': 130}
# 99999  {'id': 12, 'name': 'Product M', 'price': 40}
# 99999  {'id': 4, 'name': 'Product E', 'price': 120}
# 99999  {'id': 0, 'name': 'Product A', 'price': 160}
# 99999  {'id': 2, 'name': 'Product C', 'price': 140}
#
#                                                       user  product_id  \
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        0
# 0      {'id': 3, 'name': 'User D', 'city': 'Sydney'}        8
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        3
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        2
# 1      {'id': 0, 'name': 'User A', 'city': 'Prague'}        13
# ...                                              ...        ..
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  3
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  12
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  4
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  0
# 99999  {'id': 7, 'name': 'User H', 'city': 'Kuala Lumpur'}  2
#
#       product_name  product_price  user_id user_name     user_city  row_id
# 0      Product A    160            3        User D    Sydney        0
# 0      Product I    80             3        User D    Sydney        0
# 1      Product D    130            0        User A    Prague        1
# 1      Product C    140            0        User A    Prague        1
# 1      Product N    30             0        User A    Prague        1
# ...          ...    ..            ..           ...       ...       ..
# 99999  Product D    130            7        User H    Kuala Lumpur  99999
# 99999  Product M    40             7        User H    Kuala Lumpur  99999
# 99999  Product E    120            7        User H    Kuala Lumpur  99999
# 99999  Product A    160            7        User H    Kuala Lumpur  99999
# 99999  Product C    140            7        User H    Kuala Lumpur  99999
#
# [549145 rows x 11 columns]

# %%
# Group data
grouped_data = df_expanded.groupby(['user_id', 'user_city', 'product_id'])

# %%
# Determine size and add column quantity
df_grouped = grouped_data.size().reset_index(name='quantity')

# %%
sorted_data = df_grouped.sort_values(['user_city', 'quantity'], ascending=[True, False])

# %%
sorted_data.groupby('user_city').head(3)
# Out:
#      user_id     user_city  product_id  quantity
# 27   1        Brno          11          4438
# 30   1        Brno          14          4413
# 29   1        Brno          13          4386
# 104  6        Hong Kong     8           4415
# 111  6        Hong Kong     15          4397
# 110  6        Hong Kong     14          4369
# 83   5        Jakarta       3           4328
# 89   5        Jakarta       9           4309
# 82   5        Jakarta       2           4305
# 113  7        Kuala Lumpur  1           4446
# 123  7        Kuala Lumpur  11          4338
# 121  7        Kuala Lumpur  9           4336
# 73   4        Melbourne     9           4438
# 67   4        Melbourne     3           4400
# 72   4        Melbourne     8           4391
# 2    0        Prague        2           4400
# 11   0        Prague        11          4388
# 6    0        Prague        6           4362
# 47   2        Singapore     15          4479
# 45   2        Singapore     13          4396
# 34   2        Singapore     2           4381
# 60   3        Sydney        12          4335
# 58   3        Sydney        10          4318
# 59   3        Sydney        11          4313

# %%
# Determine top product per city
top_products_per_city = sorted_data.groupby('user_city').head(3)

# %%
top_products_per_city.reset_index(drop=True, inplace=True)
top_products_per_city
# Out:
#     user_id     user_city  product_id  quantity
# 0   1        Brno          11          4438
# 1   1        Brno          14          4413
# 2   1        Brno          13          4386
# 3   6        Hong Kong     8           4415
# 4   6        Hong Kong     15          4397
# 5   6        Hong Kong     14          4369
# 6   5        Jakarta       3           4328
# 7   5        Jakarta       9           4309
# 8   5        Jakarta       2           4305
# 9   7        Kuala Lumpur  1           4446
# 10  7        Kuala Lumpur  11          4338
# 11  7        Kuala Lumpur  9           4336
# 12  4        Melbourne     9           4438
# 13  4        Melbourne     3           4400
# 14  4        Melbourne     8           4391
# 15  0        Prague        2           4400
# 16  0        Prague        11          4388
# 17  0        Prague        6           4362
# 18  2        Singapore     15          4479
# 19  2        Singapore     13          4396
# 20  2        Singapore     2           4381
# 21  3        Sydney        12          4335
# 22  3        Sydney        10          4318
# 23  3        Sydney        11          4313

# %%
# Merge data from original df to exctract data information about product
result_data = pd.merge(top_products_per_city[['user_id', 'user_city', 'product_id', 'quantity']],
                       df_expanded[['user_id', 'product_id', 'product_name', 'product_price']],
                       on=['user_id', 'product_id'], how='left')

# Drop duplicate rows to keep only the 25 rows from top_products_per_city
result_data = result_data.drop_duplicates(subset=['user_id', 'product_id'])

# Display the result
result_data.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Best 3 products for each city based on quantity with specification of product_name and product_price

# %%
print(result_data)
# Out:
#     user_id     user_city  product_id  quantity product_name  product_price
# 0   1        Brno          11          4438      Product L    50
# 1   1        Brno          14          4413      Product O    20
# 2   1        Brno          13          4386      Product N    30
# 3   6        Hong Kong     8           4415      Product I    80
# 4   6        Hong Kong     15          4397      Product P    10
# 5   6        Hong Kong     14          4369      Product O    20
# 6   5        Jakarta       3           4328      Product D    130
# 7   5        Jakarta       9           4309      Product J    70
# 8   5        Jakarta       2           4305      Product C    140
# 9   7        Kuala Lumpur  1           4446      Product B    150
# 10  7        Kuala Lumpur  11          4338      Product L    50
# 11  7        Kuala Lumpur  9           4336      Product J    70
# 12  4        Melbourne     9           4438      Product J    70
# 13  4        Melbourne     3           4400      Product D    130
# 14  4        Melbourne     8           4391      Product I    80
# 15  0        Prague        2           4400      Product C    140
# 16  0        Prague        11          4388      Product L    50
# 17  0        Prague        6           4362      Product G    100
# 18  2        Singapore     15          4479      Product P    10
# 19  2        Singapore     13          4396      Product N    30
# 20  2        Singapore     2           4381      Product C    140
# 21  3        Sydney        12          4335      Product M    40
# 22  3        Sydney        10          4318      Product K    60
# 23  3        Sydney        11          4313      Product L    50
